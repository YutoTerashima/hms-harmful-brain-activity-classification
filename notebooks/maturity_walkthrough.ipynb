# %% [markdown]
# # HMS Harmful Brain Activity Classification walkthrough\n\nResearch question: How can a Kaggle Silver Medal EEG solution be packaged as a reproducible, inspectable research archive?\n

# %% [markdown]
# ## What to inspect\n\n- README result table\n- `reports/results/experiment_index.json`\n- `reports/hms_solution_showcase_report.md`\n- maturity review report\n

# %%
from pathlib import Path\nimport json\nroot = Path('..').resolve()\nindex_path = root / 'reports' / 'results' / 'experiment_index.json'\nif index_path.exists():\n    index = json.loads(index_path.read_text())\n    print(index.get('title'))\n    print('results:', len(index.get('results', [])))\n    print('artifacts:', len(index.get('artifacts', [])))\nelse:\n    print('Showcase/archive repo: inspect reports and notebooks directly.')\n

# %% [markdown]
# ## Interpretation\n\n- The project is a credible competition archive because it preserves original notebooks and adds clean package structure.\n- The strongest signal is the Kaggle Silver Medal result plus an inspectable ensemble workflow.\n- Raw data is excluded, so reproduction depends on Kaggle API access and the provided data card.\n
